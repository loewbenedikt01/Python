# %% [markdown]
# ****Scikit-learn****

# %%
import pandas as pd
import yfinance as yf
import numpy as np
from datetime import date

# %%
ticker = 'MSFT'
start_date = '2020-01-01'
end_date = '2025-12-31'

df = yf.download(ticker, start_date, end_date)
# Out:
# C:\Users\benel\AppData\Local\Temp\ipykernel_26248\155153850.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df.columns = df.columns.droplevel(1)

df.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2020-01-02  151.829544  151.933525  149.664878  150.090248  22622100
# 2020-01-03  149.939011  151.196224  149.409661  149.655441  21116200
# 2020-01-06  150.326569  150.392745  147.944480  148.483292  20813700
# 2020-01-07  148.955902  150.931516  148.710137  150.600680  21634100
# 2020-01-08  151.328537  151.999686  149.305656  150.232018  27746500

# %%
df['Return'] = df['Close'].pct_change()

df['SMA20'] = df['Close'].rolling(20).mean()
df['SMA50'] = df['Close'].rolling(50).mean()

df['Volatility'] = df['Return'].rolling(20).std()

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-12-23  484.691528  485.667164  482.590867  482.829824  14683600
# 2025-12-24  485.856323  486.991284  482.680464  483.526701   5855900
# 2025-12-26  485.547699  485.955885  483.805458  484.552133   8842200
# 2025-12-29  484.940430  486.184888  482.033362  482.710340  10893400
# 2025-12-30  485.318726  487.508953  483.347493  483.775579  13944500
#
# Price         Return       SMA20       SMA50  Volatility
# Date
# 2025-12-23  0.003980  481.135867  496.477027    0.012476
# 2025-12-24  0.002403  481.684923  495.987395    0.012425
# 2025-12-26 -0.000635  481.794931  495.494373    0.011795
# 2025-12-29 -0.001251  481.550519  495.025377    0.011386
# 2025-12-30  0.000780  481.587355  494.524794    0.011127

# %%
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-12-23  484.691528  485.667164  482.590867  482.829824  14683600
# 2025-12-24  485.856323  486.991284  482.680464  483.526701   5855900
# 2025-12-26  485.547699  485.955885  483.805458  484.552133   8842200
# 2025-12-29  484.940430  486.184888  482.033362  482.710340  10893400
# 2025-12-30  485.318726  487.508953  483.347493  483.775579  13944500
#
# Price         Return       SMA20       SMA50  Volatility  Target
# Date
# 2025-12-23  0.003980  481.135867  496.477027    0.012476       1
# 2025-12-24  0.002403  481.684923  495.987395    0.012425       0
# 2025-12-26 -0.000635  481.794931  495.494373    0.011795       0
# 2025-12-29 -0.001251  481.550519  495.025377    0.011386       1
# 2025-12-30  0.000780  481.587355  494.524794    0.011127       0

# %%
import sklearn

# %%
df = df.dropna(subset=['SMA50', 'Target'])

X = df[['SMA50']]

y = df['Target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

# %%
split = int(len(df) * 0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression()
# ----> 5 model.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1239, in LogisticRegression.fit(self, X, y, sample_weight)
#    1236 else:
#    1237     _dtype = [np.float64, np.float32]
# -> 1239 X, y = validate_data(
#    1240     self,
#    1241     X,
#    1242     y,
#    1243     accept_sparse="csr",
#    1244     dtype=_dtype,
#    1245     order="C",
#    1246     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1247 )
#    1248 check_classification_targets(y)
#    1249 self.classes_ = np.unique(y)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
predictions = model.predict(X_test)

print(predictions[:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 predictions = model.predict(X_test)
#       3 print(predictions[:10])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_base.py:353, in LinearClassifierMixin.decision_function(self, X)
#     350 xp, _ = get_namespace(X)
#     352 X = validate_data(self, X, accept_sparse="csr", reset=False)
# --> 353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 from sklearn.metrics import accuracy_score
# ----> 3 accuracy = accuracy_score(y_test, predictions)
#       5 print("Accuracy:", accuracy)
#
# NameError: name 'predictions' is not defined
